# %% [markdown]
# # The goal of this notebook is to develop and document algorithm detecting values on 7 segment displays

# %%
import cv2
import os
from matplotlib import pyplot as plt

# %%
img = cv2.imread("data/22.jpg")
img = img[:,:,::-1]
plt.imshow(img)

# %% [markdown]
# ## Notes:
# 1. We can detect displays based on their background
#     - reed on black
#     - and black on like gray or smth
#
#     This should suffice to cut the image into slices, and than we can analyze every image one by one
# 2. Multimeter display ios very reflective this is a problem
